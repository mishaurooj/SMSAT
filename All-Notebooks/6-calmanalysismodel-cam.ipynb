# %%
pip install XlsxWriter
# Out:
# Collecting XlsxWriter
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 4.0 MB/s eta 0:00:0000:01
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-3.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import os
import librosa
import numpy as np
import pywt
import time
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import copy
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report  # Added classification_report

# Ensure device compatibility
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ====================
# 1. Dataset & Feature Extraction
# ====================

class QMSAT(Dataset):  # Renamed dataset to QMSAT
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.file_paths = []
        self.labels = []
        self.class_counts = Counter()

        class_mapping = {"Music": 0, "Normal(Silence)": 1, "Tilawat-e-QuranPak": 2}

        for category in os.listdir(root_dir):
            category_path = os.path.join(root_dir, category)
            if os.path.isdir(category_path):
                label = class_mapping.get(category, -1)
                if label == -1:
                    continue
                for file in os.listdir(category_path):
                    if file.endswith(".wav"):
                        self.file_paths.append(os.path.join(category_path, file))
                        self.labels.append(label)
                        self.class_counts[label] += 1

        # Compute class weights for balancing
        total_samples = sum(self.class_counts.values())
        self.class_weights = {k: total_samples / v for k, v in self.class_counts.items()}

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        file_path = self.file_paths[idx]
        label = self.labels[idx]
        waveform, sr = librosa.load(file_path, sr=16000)

        # Extract features
        mfcc_features = self.extract_mfcc_features(waveform)
        time_features = self.extract_time_features(waveform)
        wavelet_features = self.extract_wavelet_features(waveform)

        # Combine all features
        combined_features = np.concatenate([mfcc_features, time_features, wavelet_features])

        if combined_features.shape[0] != 25:
            raise ValueError(f"Expected 25 features, got {combined_features.shape[0]}.")
        
        return torch.tensor(combined_features, dtype=torch.float32), torch.tensor(label)

    def extract_mfcc_features(self, waveform, sr=16000, n_mfcc=13):
        mfccs = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=n_mfcc)
        return mfccs.mean(axis=1)

    def extract_time_features(self, waveform):
        zcr = librosa.feature.zero_crossing_rate(waveform)[0].mean()
        rms = librosa.feature.rms(y=waveform)[0].mean()
        return np.array([zcr, rms])

    def extract_wavelet_features(self, waveform):
        coeffs = pywt.wavedec(waveform, 'db4', level=4)
        features = []
        for c in coeffs:
            features.append(np.mean(c) if c.size > 0 else 0)
            features.append(np.std(c) if c.size > 0 else 0)
        return np.array(features[:10])

# ====================
# 2. Initialize Dataset & DataLoader
# ====================

dataset = QMSAT(root_dir="/kaggle/input/qmsat-dataset/ATS-data")  # Using renamed dataset QMSAT
sample_weights = [dataset.class_weights[label] for label in dataset.labels]
sampler = WeightedRandomSampler(sample_weights, num_samples=len(sample_weights), replacement=True)
data_loader = DataLoader(dataset, batch_size=512, sampler=sampler)

# ====================
# 3. Model Definition
# ====================

class CalmnessAnalysisModel(nn.Module):
    def __init__(self, input_dim=25, hidden_dim=256, num_classes=3):
        super(CalmnessAnalysisModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(hidden_dim * 2, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.3)

    def forward(self, audio_features):
        # Add sequence dimension
        audio_features = audio_features.unsqueeze(1)
        lstm_out, _ = self.lstm(audio_features)
        lstm_out = lstm_out[:, -1, :]
        x = self.relu(self.fc1(lstm_out))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# ====================
# 4. Training Process
# ====================

model = CalmnessAnalysisModel(input_dim=25).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.005)
criterion = nn.CrossEntropyLoss()

train_losses, train_accuracies, epoch_times = [], [], []
best_loss = float('inf')
best_epoch = 0
best_model_wts = copy.deepcopy(model.state_dict())

total_start_time = time.time()

for epoch in range(350):
    model.train()
    correct, total = 0, 0
    epoch_loss = 0
    epoch_start_time = time.time()

    for audio_features, labels in data_loader:
        audio_features, labels = audio_features.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(audio_features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        predictions = outputs.argmax(dim=1)
        correct += (predictions == labels).sum().item()
        total += labels.size(0)

    epoch_duration = time.time() - epoch_start_time
    train_losses.append(epoch_loss)
    train_accuracies.append(correct / total)
    epoch_times.append(epoch_duration)

    print(f"Epoch {epoch + 1} | Loss: {epoch_loss:.4f} | Accuracy: {100 * (correct / total):.2f}% | Time: {epoch_duration:.2f}s")

    if epoch_loss < best_loss:
        best_loss = epoch_loss
        best_epoch = epoch + 1
        best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(best_model_wts, "/kaggle/working/best_calmness_analysis_model.pth")

# Save the best model
model.load_state_dict(best_model_wts)
torch.save(model.state_dict(), "/kaggle/working/calmness_analysis_model.pth")

# -------------------------------
# Print Model Summary & Parameters
# -------------------------------

print("\nModel Summary:")
from torchinfo import summary
print(summary(model, input_size=(512, 25), col_names=["input_size", "output_size", "num_params", "mult_adds"], depth=2))

# -------------------------------
# Print Total GPU Training Time & Hyperparameters
# -------------------------------
total_training_time = time.time() - total_start_time
print(f"\nTotal GPU Training Time: {total_training_time:.2f} seconds")
print("Hyperparameters Used:")
print("Learning Rate: 0.005")
print("Epochs: 350")
print("Batch Size: 512")
print("Input Dimension: 25")
print("Hidden Dimension: 256")
print("Dropout: 0.3")
print("Optimizer: Adam")
print("Criterion: CrossEntropyLoss")

# ====================
# 5. Training Results & Visualization
# ====================

df = pd.DataFrame({
    "Epoch": range(1, len(train_losses) + 1),
    "Loss": train_losses,
    "Accuracy": train_accuracies,
    "Time (s)": epoch_times
})
df.to_excel("/kaggle/working/training_results.xlsx", index=False)

# Professional Plot with Multiple Subplots
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(df["Epoch"], df["Loss"], marker="o", label="Train Loss", color="blue")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss", color="blue")
ax.tick_params(axis="y", labelcolor="blue")

ax2 = ax.twinx()
ax2.plot(df["Epoch"], df["Accuracy"], marker="s", label="Train Accuracy", color="green")
ax2.set_ylabel("Accuracy", color="green")
ax2.tick_params(axis="y", labelcolor="green")

ax3 = ax.twinx()
ax3.spines["right"].set_position(("outward", 60))
ax3.plot(df["Epoch"], df["Time (s)"], marker="^", label="Epoch Time", color="red")
ax3.set_ylabel("Epoch Time (s)", color="red")
ax3.tick_params(axis="y", labelcolor="red")

plt.title("Training Loss, Accuracy, and Epoch Time")
fig.legend(loc="upper right", bbox_to_anchor=(1,1))
plt.savefig("/kaggle/working/training_performance.jpeg", dpi=300)
plt.show()

# ------------------------------- 
# Save All Results to Excel
# -------------------------------

# Save all results to a single Excel file with multiple sheets
hyperparameters = {
    "Learning Rate": 0.005,
    "Epochs": 350,
    "Batch Size": 512,
    "Input Dimension": 25,
    "Hidden Dimension": 256,
    "Dropout": 0.3,
    "Optimizer": "Adam",
    "Criterion": "CrossEntropyLoss",
    "Total GPU Training Time (s)": total_training_time
}

hyper_df = pd.DataFrame(list(hyperparameters.items()), columns=["Parameter", "Value"])

with pd.ExcelWriter("/kaggle/working/all_results.xlsx") as writer:
    df.to_excel(writer, sheet_name="Training Results", index=False)
    hyper_df.to_excel(writer, sheet_name="Hyperparameters", index=False)
# Out:
# Using device: cuda
# Epoch 1 | Loss: 1.0962 | Accuracy: 34.04% | Time: 25.37s
# Epoch 2 | Loss: 1.0966 | Accuracy: 36.88% | Time: 9.97s
# Epoch 3 | Loss: 1.1300 | Accuracy: 34.75% | Time: 9.62s
# Epoch 4 | Loss: 1.0994 | Accuracy: 34.75% | Time: 9.33s
# Epoch 5 | Loss: 1.0889 | Accuracy: 41.84% | Time: 9.39s
# Epoch 6 | Loss: 1.0928 | Accuracy: 40.43% | Time: 8.96s
# Epoch 7 | Loss: 1.1021 | Accuracy: 35.46% | Time: 9.28s
# Epoch 8 | Loss: 1.0852 | Accuracy: 37.59% | Time: 8.83s
# Epoch 9 | Loss: 1.0544 | Accuracy: 39.01% | Time: 9.00s
# Epoch 10 | Loss: 1.0845 | Accuracy: 41.13% | Time: 9.14s
# Epoch 11 | Loss: 1.0689 | Accuracy: 39.01% | Time: 9.15s
# Epoch 12 | Loss: 1.0717 | Accuracy: 41.13% | Time: 9.18s
# Epoch 13 | Loss: 1.0323 | Accuracy: 45.39% | Time: 9.36s
# Epoch 14 | Loss: 1.0754 | Accuracy: 39.01% | Time: 9.22s
# Epoch 15 | Loss: 1.0718 | Accuracy: 38.30% | Time: 9.09s
# Epoch 16 | Loss: 1.0492 | Accuracy: 46.10% | Time: 8.89s
# Epoch 17 | Loss: 1.0350 | Accuracy: 43.97% | Time: 9.21s
# Epoch 18 | Loss: 1.0439 | Accuracy: 40.43% | Time: 8.95s
# Epoch 19 | Loss: 1.0209 | Accuracy: 43.97% | Time: 9.11s
# Epoch 20 | Loss: 1.0099 | Accuracy: 49.65% | Time: 9.14s
# Epoch 21 | Loss: 1.0690 | Accuracy: 35.46% | Time: 8.84s
# Epoch 22 | Loss: 1.0612 | Accuracy: 43.97% | Time: 9.14s
# Epoch 23 | Loss: 0.9985 | Accuracy: 53.19% | Time: 9.16s
# Epoch 24 | Loss: 1.0079 | Accuracy: 49.65% | Time: 8.95s
# Epoch 25 | Loss: 1.0277 | Accuracy: 43.26% | Time: 9.07s
# Epoch 26 | Loss: 0.9221 | Accuracy: 58.87% | Time: 9.05s
# Epoch 27 | Loss: 1.0029 | Accuracy: 45.39% | Time: 8.95s
# Epoch 28 | Loss: 1.0029 | Accuracy: 44.68% | Time: 9.43s
# Epoch 29 | Loss: 0.9639 | Accuracy: 46.10% | Time: 8.86s
# Epoch 30 | Loss: 0.9510 | Accuracy: 53.90% | Time: 9.06s
# Epoch 31 | Loss: 0.9556 | Accuracy: 54.61% | Time: 8.72s
# Epoch 32 | Loss: 0.9178 | Accuracy: 50.35% | Time: 9.14s
# Epoch 33 | Loss: 0.9074 | Accuracy: 52.48% | Time: 9.16s
# Epoch 34 | Loss: 0.9054 | Accuracy: 51.06% | Time: 9.11s
# Epoch 35 | Loss: 0.9143 | Accuracy: 48.94% | Time: 9.27s
# Epoch 36 | Loss: 0.9083 | Accuracy: 51.77% | Time: 9.08s
# Epoch 37 | Loss: 0.9197 | Accuracy: 50.35% | Time: 9.16s
# Epoch 38 | Loss: 0.9147 | Accuracy: 54.61% | Time: 8.83s
# Epoch 39 | Loss: 0.9455 | Accuracy: 46.81% | Time: 9.10s
# Epoch 40 | Loss: 0.8667 | Accuracy: 53.19% | Time: 8.80s
# Epoch 41 | Loss: 0.9031 | Accuracy: 54.61% | Time: 9.41s
# Epoch 42 | Loss: 0.8593 | Accuracy: 54.61% | Time: 9.65s
# Epoch 43 | Loss: 0.8832 | Accuracy: 50.35% | Time: 9.10s
# Epoch 44 | Loss: 0.8313 | Accuracy: 58.16% | Time: 9.34s
# Epoch 45 | Loss: 0.8022 | Accuracy: 60.99% | Time: 9.58s
# Epoch 46 | Loss: 0.9070 | Accuracy: 51.06% | Time: 9.25s
# Epoch 47 | Loss: 0.7747 | Accuracy: 63.12% | Time: 9.42s
# Epoch 48 | Loss: 0.9006 | Accuracy: 50.35% | Time: 9.37s
# Epoch 49 | Loss: 0.8245 | Accuracy: 58.16% | Time: 9.29s
# Epoch 50 | Loss: 0.7534 | Accuracy: 62.41% | Time: 9.19s
# Epoch 51 | Loss: 0.8092 | Accuracy: 55.32% | Time: 9.17s
# Epoch 52 | Loss: 0.7542 | Accuracy: 59.57% | Time: 9.16s
# Epoch 53 | Loss: 0.7236 | Accuracy: 68.09% | Time: 9.55s
# Epoch 54 | Loss: 0.7821 | Accuracy: 63.12% | Time: 9.63s
# Epoch 55 | Loss: 0.7344 | Accuracy: 65.25% | Time: 9.29s
# Epoch 56 | Loss: 0.7775 | Accuracy: 57.45% | Time: 9.42s
# Epoch 57 | Loss: 0.7222 | Accuracy: 64.54% | Time: 9.33s
# Epoch 58 | Loss: 0.8110 | Accuracy: 61.70% | Time: 9.32s
# Epoch 59 | Loss: 0.7120 | Accuracy: 64.54% | Time: 9.36s
# Epoch 60 | Loss: 0.7748 | Accuracy: 56.03% | Time: 9.18s
# Epoch 61 | Loss: 0.7320 | Accuracy: 67.38% | Time: 9.61s
# Epoch 62 | Loss: 0.6646 | Accuracy: 70.21% | Time: 9.09s
# Epoch 63 | Loss: 0.7144 | Accuracy: 65.96% | Time: 9.32s
# Epoch 64 | Loss: 0.6779 | Accuracy: 67.38% | Time: 9.39s
# Epoch 65 | Loss: 0.6495 | Accuracy: 68.09% | Time: 9.27s
# Epoch 66 | Loss: 0.7333 | Accuracy: 58.16% | Time: 9.33s
# Epoch 67 | Loss: 0.7027 | Accuracy: 70.21% | Time: 9.52s
# Epoch 68 | Loss: 0.7545 | Accuracy: 60.28% | Time: 10.00s
# Epoch 69 | Loss: 0.6604 | Accuracy: 67.38% | Time: 9.25s
# Epoch 70 | Loss: 0.6496 | Accuracy: 69.50% | Time: 9.21s
# Epoch 71 | Loss: 0.7233 | Accuracy: 62.41% | Time: 9.19s
# Epoch 72 | Loss: 0.6689 | Accuracy: 70.21% | Time: 9.16s
# Epoch 73 | Loss: 0.7157 | Accuracy: 66.67% | Time: 9.22s
# Epoch 74 | Loss: 0.7355 | Accuracy: 66.67% | Time: 9.20s
# Epoch 75 | Loss: 0.5831 | Accuracy: 73.05% | Time: 9.07s
# Epoch 76 | Loss: 0.6708 | Accuracy: 70.92% | Time: 9.10s
# Epoch 77 | Loss: 0.6173 | Accuracy: 67.38% | Time: 9.49s
# Epoch 78 | Loss: 0.6330 | Accuracy: 68.09% | Time: 9.67s
# Epoch 79 | Loss: 0.6530 | Accuracy: 70.21% | Time: 9.45s
# Epoch 80 | Loss: 0.6197 | Accuracy: 69.50% | Time: 9.79s
# Epoch 81 | Loss: 0.6835 | Accuracy: 63.12% | Time: 9.32s
# Epoch 82 | Loss: 0.6184 | Accuracy: 68.79% | Time: 9.66s
# Epoch 83 | Loss: 0.8962 | Accuracy: 56.03% | Time: 9.77s
# Epoch 84 | Loss: 0.6584 | Accuracy: 68.79% | Time: 9.30s
# Epoch 85 | Loss: 0.6621 | Accuracy: 68.09% | Time: 9.18s
# Epoch 86 | Loss: 0.6030 | Accuracy: 70.21% | Time: 9.17s
# Epoch 87 | Loss: 0.6116 | Accuracy: 68.09% | Time: 9.71s
# Epoch 88 | Loss: 0.6027 | Accuracy: 68.79% | Time: 9.73s
# Epoch 89 | Loss: 0.5680 | Accuracy: 74.47% | Time: 9.46s
# Epoch 100 | Loss: 0.5097 | Accuracy: 78.01% | Time: 9.85s
# Epoch 101 | Loss: 0.5388 | Accuracy: 78.72% | Time: 9.66s
# Epoch 102 | Loss: 0.4991 | Accuracy: 83.69% | Time: 9.38s
# Epoch 103 | Loss: 0.4375 | Accuracy: 78.72% | Time: 9.52s
# Epoch 104 | Loss: 0.4774 | Accuracy: 79.43% | Time: 9.45s
# Epoch 105 | Loss: 0.4184 | Accuracy: 80.14% | Time: 9.38s
# Epoch 106 | Loss: 0.4844 | Accuracy: 75.18% | Time: 9.30s
# Epoch 107 | Loss: 0.4831 | Accuracy: 78.72% | Time: 9.45s
# Epoch 108 | Loss: 0.4457 | Accuracy: 78.72% | Time: 9.01s
# Epoch 109 | Loss: 0.5008 | Accuracy: 80.85% | Time: 9.06s
# Epoch 110 | Loss: 0.4714 | Accuracy: 82.27% | Time: 9.20s
# Epoch 111 | Loss: 0.5529 | Accuracy: 76.60% | Time: 9.28s
# Epoch 112 | Loss: 0.5366 | Accuracy: 78.72% | Time: 9.03s
# Epoch 113 | Loss: 0.6322 | Accuracy: 68.79% | Time: 9.00s
# Epoch 114 | Loss: 0.5164 | Accuracy: 76.60% | Time: 9.21s
# Epoch 115 | Loss: 0.4920 | Accuracy: 76.60% | Time: 9.22s
# Epoch 116 | Loss: 0.5223 | Accuracy: 74.47% | Time: 8.89s
# Epoch 117 | Loss: 0.5201 | Accuracy: 77.30% | Time: 9.26s
# Epoch 118 | Loss: 0.6109 | Accuracy: 73.76% | Time: 9.10s
# Epoch 119 | Loss: 0.4792 | Accuracy: 82.98% | Time: 9.22s
# Epoch 120 | Loss: 0.4723 | Accuracy: 78.72% | Time: 9.47s
# Epoch 121 | Loss: 0.5216 | Accuracy: 70.92% | Time: 8.98s
# Epoch 122 | Loss: 0.5062 | Accuracy: 81.56% | Time: 8.76s
# Epoch 123 | Loss: 0.4226 | Accuracy: 84.40% | Time: 8.96s
# Epoch 124 | Loss: 0.5113 | Accuracy: 78.72% | Time: 9.06s
# Epoch 125 | Loss: 0.3997 | Accuracy: 81.56% | Time: 8.91s
# Epoch 126 | Loss: 0.3847 | Accuracy: 85.11% | Time: 9.22s
# Epoch 127 | Loss: 0.4412 | Accuracy: 79.43% | Time: 9.09s
# Epoch 128 | Loss: 0.3728 | Accuracy: 85.82% | Time: 8.93s
# Epoch 129 | Loss: 0.4208 | Accuracy: 82.98% | Time: 9.16s
# Epoch 130 | Loss: 0.5127 | Accuracy: 78.01% | Time: 9.11s
# Epoch 131 | Loss: 0.3415 | Accuracy: 90.07% | Time: 9.34s
# Epoch 132 | Loss: 0.4678 | Accuracy: 80.14% | Time: 9.23s
# Epoch 133 | Loss: 0.3300 | Accuracy: 87.23% | Time: 9.27s
# Epoch 134 | Loss: 0.3885 | Accuracy: 81.56% | Time: 9.31s
# Epoch 135 | Loss: 0.4532 | Accuracy: 82.27% | Time: 9.01s
# Epoch 136 | Loss: 0.3168 | Accuracy: 90.07% | Time: 9.14s
# Epoch 137 | Loss: 0.3702 | Accuracy: 84.40% | Time: 8.86s
# Epoch 138 | Loss: 0.3822 | Accuracy: 83.69% | Time: 9.05s
# Epoch 139 | Loss: 0.3570 | Accuracy: 84.40% | Time: 9.26s
# Epoch 140 | Loss: 0.4080 | Accuracy: 80.85% | Time: 9.15s
# Epoch 141 | Loss: 0.4678 | Accuracy: 79.43% | Time: 10.45s
# Epoch 142 | Loss: 0.3220 | Accuracy: 90.07% | Time: 9.78s
# Epoch 143 | Loss: 0.3132 | Accuracy: 85.82% | Time: 9.40s
# Epoch 144 | Loss: 0.4370 | Accuracy: 82.98% | Time: 9.93s
# Epoch 145 | Loss: 0.4262 | Accuracy: 82.27% | Time: 9.53s
# Epoch 146 | Loss: 0.3307 | Accuracy: 87.94% | Time: 9.57s
# Epoch 147 | Loss: 0.3346 | Accuracy: 85.82% | Time: 9.61s
# Epoch 148 | Loss: 0.3822 | Accuracy: 83.69% | Time: 9.79s
# Epoch 149 | Loss: 0.3556 | Accuracy: 85.82% | Time: 9.51s
# Epoch 150 | Loss: 0.2656 | Accuracy: 90.07% | Time: 9.78s
# Epoch 151 | Loss: 0.4652 | Accuracy: 76.60% | Time: 9.61s
# Epoch 152 | Loss: 0.3470 | Accuracy: 88.65% | Time: 10.12s
# Epoch 153 | Loss: 0.3924 | Accuracy: 84.40% | Time: 9.60s
# Epoch 154 | Loss: 0.3060 | Accuracy: 90.07% | Time: 9.92s
# Epoch 155 | Loss: 0.3138 | Accuracy: 87.23% | Time: 9.96s
# Epoch 156 | Loss: 0.3017 | Accuracy: 89.36% | Time: 9.65s
# Epoch 157 | Loss: 0.2770 | Accuracy: 89.36% | Time: 9.20s
# Epoch 158 | Loss: 0.2201 | Accuracy: 91.49% | Time: 9.31s
# Epoch 159 | Loss: 0.2927 | Accuracy: 87.94% | Time: 9.35s
# Epoch 160 | Loss: 0.3579 | Accuracy: 84.40% | Time: 9.22s
# Epoch 161 | Loss: 0.2551 | Accuracy: 92.20% | Time: 9.28s
# Epoch 162 | Loss: 0.4553 | Accuracy: 80.14% | Time: 9.28s
# Epoch 163 | Loss: 0.3273 | Accuracy: 85.82% | Time: 9.19s
# Epoch 164 | Loss: 0.6236 | Accuracy: 74.47% | Time: 9.02s
# Epoch 165 | Loss: 0.3607 | Accuracy: 88.65% | Time: 9.49s
# Epoch 166 | Loss: 0.3533 | Accuracy: 80.85% | Time: 9.01s
# Epoch 167 | Loss: 0.4159 | Accuracy: 82.27% | Time: 9.35s
# Epoch 168 | Loss: 0.3229 | Accuracy: 86.52% | Time: 9.04s
# Epoch 169 | Loss: 0.3191 | Accuracy: 86.52% | Time: 9.26s
# Epoch 170 | Loss: 0.3748 | Accuracy: 80.85% | Time: 9.43s
# Epoch 171 | Loss: 0.3370 | Accuracy: 88.65% | Time: 9.16s
# Epoch 172 | Loss: 0.3157 | Accuracy: 86.52% | Time: 9.39s
# Epoch 173 | Loss: 0.3532 | Accuracy: 83.69% | Time: 9.53s
# Epoch 174 | Loss: 0.3278 | Accuracy: 84.40% | Time: 9.35s
# Epoch 175 | Loss: 0.3606 | Accuracy: 82.27% | Time: 9.89s
# Epoch 176 | Loss: 0.2710 | Accuracy: 92.20% | Time: 9.41s
# Epoch 177 | Loss: 0.3906 | Accuracy: 82.27% | Time: 9.65s
# Epoch 178 | Loss: 0.2760 | Accuracy: 87.23% | Time: 9.21s
# Epoch 179 | Loss: 0.2208 | Accuracy: 94.33% | Time: 9.17s
# Epoch 180 | Loss: 0.3072 | Accuracy: 89.36% | Time: 9.16s
# Epoch 181 | Loss: 0.2281 | Accuracy: 89.36% | Time: 9.26s
# Epoch 182 | Loss: 0.2617 | Accuracy: 90.07% | Time: 9.42s
# Epoch 183 | Loss: 0.2790 | Accuracy: 88.65% | Time: 9.42s
# Epoch 184 | Loss: 0.2533 | Accuracy: 92.20% | Time: 9.51s
# Epoch 185 | Loss: 0.2970 | Accuracy: 87.94% | Time: 9.53s
# Epoch 186 | Loss: 0.3368 | Accuracy: 87.23% | Time: 9.49s
# Epoch 187 | Loss: 0.2703 | Accuracy: 90.07% | Time: 9.45s
# Epoch 188 | Loss: 0.2611 | Accuracy: 89.36% | Time: 9.49s
# Epoch 189 | Loss: 0.3022 | Accuracy: 89.36% | Time: 9.76s
# Epoch 190 | Loss: 0.3221 | Accuracy: 84.40% | Time: 9.64s
# Epoch 191 | Loss: 0.2425 | Accuracy: 88.65% | Time: 9.53s
# Epoch 192 | Loss: 0.2693 | Accuracy: 87.94% | Time: 9.86s
# Epoch 193 | Loss: 0.2149 | Accuracy: 91.49% | Time: 9.36s
# Epoch 194 | Loss: 0.2675 | Accuracy: 87.94% | Time: 9.79s
# Epoch 195 | Loss: 0.2011 | Accuracy: 92.20% | Time: 9.90s
# Epoch 196 | Loss: 0.2326 | Accuracy: 91.49% | Time: 9.63s
# Epoch 197 | Loss: 0.2371 | Accuracy: 91.49% | Time: 9.87s
# Epoch 198 | Loss: 0.1809 | Accuracy: 95.04% | Time: 9.40s
# Epoch 199 | Loss: 0.2666 | Accuracy: 91.49% | Time: 9.72s
# Epoch 200 | Loss: 0.2023 | Accuracy: 92.91% | Time: 9.35s
# Epoch 201 | Loss: 0.2399 | Accuracy: 90.78% | Time: 9.65s
# Epoch 202 | Loss: 0.2371 | Accuracy: 92.91% | Time: 9.69s
# Epoch 203 | Loss: 0.2049 | Accuracy: 93.62% | Time: 9.44s
# Epoch 204 | Loss: 0.2282 | Accuracy: 90.78% | Time: 9.44s
# Epoch 205 | Loss: 0.2065 | Accuracy: 92.20% | Time: 9.62s
# Epoch 206 | Loss: 0.2174 | Accuracy: 91.49% | Time: 9.51s
# Epoch 207 | Loss: 0.1684 | Accuracy: 96.45% | Time: 9.55s
# Epoch 208 | Loss: 0.1574 | Accuracy: 95.04% | Time: 9.68s
# Epoch 209 | Loss: 0.1689 | Accuracy: 95.74% | Time: 9.55s
# Epoch 210 | Loss: 0.1790 | Accuracy: 93.62% | Time: 9.73s
# Epoch 211 | Loss: 0.1120 | Accuracy: 97.87% | Time: 9.59s
# Epoch 212 | Loss: 0.1535 | Accuracy: 96.45% | Time: 10.00s
# Epoch 213 | Loss: 0.2484 | Accuracy: 90.07% | Time: 9.32s
# Epoch 214 | Loss: 0.1944 | Accuracy: 92.20% | Time: 9.14s
# Epoch 215 | Loss: 0.1800 | Accuracy: 92.91% | Time: 9.51s
# Epoch 216 | Loss: 0.2224 | Accuracy: 90.78% | Time: 9.63s
# Epoch 217 | Loss: 0.1723 | Accuracy: 92.91% | Time: 9.50s
# Epoch 218 | Loss: 0.2481 | Accuracy: 90.07% | Time: 10.10s
# Epoch 219 | Loss: 0.1646 | Accuracy: 95.74% | Time: 9.62s
# Epoch 220 | Loss: 0.1234 | Accuracy: 97.87% | Time: 9.66s
# Epoch 221 | Loss: 0.1961 | Accuracy: 92.91% | Time: 9.54s
# Epoch 222 | Loss: 0.1365 | Accuracy: 93.62% | Time: 9.66s
# Epoch 223 | Loss: 0.2986 | Accuracy: 87.94% | Time: 9.35s
# Epoch 224 | Loss: 0.1504 | Accuracy: 95.74% | Time: 9.58s
# Epoch 225 | Loss: 0.1554 | Accuracy: 95.04% | Time: 9.92s
# Epoch 226 | Loss: 0.3813 | Accuracy: 85.82% | Time: 9.26s
# Epoch 227 | Loss: 0.1288 | Accuracy: 95.04% | Time: 9.39s
# Epoch 228 | Loss: 0.4233 | Accuracy: 86.52% | Time: 9.72s
# Epoch 229 | Loss: 0.2941 | Accuracy: 87.94% | Time: 9.38s
# Epoch 230 | Loss: 0.2051 | Accuracy: 90.78% | Time: 9.47s
# Epoch 231 | Loss: 0.5889 | Accuracy: 80.14% | Time: 9.42s
# Epoch 232 | Loss: 0.1613 | Accuracy: 93.62% | Time: 9.66s
# Epoch 233 | Loss: 0.3928 | Accuracy: 82.98% | Time: 9.41s
# Epoch 234 | Loss: 0.2242 | Accuracy: 92.91% | Time: 9.35s
# Epoch 235 | Loss: 0.2391 | Accuracy: 87.23% | Time: 9.86s
# Epoch 236 | Loss: 0.2466 | Accuracy: 88.65% | Time: 9.58s
# Epoch 237 | Loss: 0.2082 | Accuracy: 91.49% | Time: 9.65s
# Epoch 238 | Loss: 0.3255 | Accuracy: 85.82% | Time: 9.54s
# Epoch 239 | Loss: 0.2139 | Accuracy: 90.07% | Time: 9.67s
# Epoch 240 | Loss: 0.2340 | Accuracy: 92.20% | Time: 9.22s
# Epoch 241 | Loss: 0.2422 | Accuracy: 91.49% | Time: 9.25s
# Epoch 242 | Loss: 0.2070 | Accuracy: 92.20% | Time: 9.38s
# Epoch 243 | Loss: 0.1958 | Accuracy: 93.62% | Time: 9.25s
# Epoch 244 | Loss: 0.3051 | Accuracy: 86.52% | Time: 9.59s
# Epoch 245 | Loss: 0.1766 | Accuracy: 94.33% | Time: 9.91s
# Epoch 246 | Loss: 0.2536 | Accuracy: 90.78% | Time: 9.53s
# Epoch 247 | Loss: 0.2003 | Accuracy: 90.07% | Time: 9.17s
# Epoch 248 | Loss: 0.1112 | Accuracy: 96.45% | Time: 9.57s
# Epoch 249 | Loss: 0.2028 | Accuracy: 91.49% | Time: 9.55s
# Epoch 250 | Loss: 0.2450 | Accuracy: 91.49% | Time: 9.41s
# Epoch 251 | Loss: 0.2237 | Accuracy: 90.78% | Time: 9.45s
# Epoch 252 | Loss: 0.2232 | Accuracy: 90.07% | Time: 9.65s
# Epoch 253 | Loss: 0.2185 | Accuracy: 91.49% | Time: 9.12s
# Epoch 254 | Loss: 0.1883 | Accuracy: 92.20% | Time: 9.21s
# Epoch 255 | Loss: 0.2066 | Accuracy: 93.62% | Time: 9.37s
# Epoch 256 | Loss: 0.2564 | Accuracy: 87.23% | Time: 9.35s
# Epoch 257 | Loss: 0.1113 | Accuracy: 97.16% | Time: 9.17s
# Epoch 258 | Loss: 0.1942 | Accuracy: 92.91% | Time: 9.19s
# Epoch 259 | Loss: 0.1302 | Accuracy: 97.16% | Time: 9.24s
# Epoch 260 | Loss: 0.3182 | Accuracy: 88.65% | Time: 9.13s
# Epoch 261 | Loss: 0.2680 | Accuracy: 88.65% | Time: 9.32s
# Epoch 262 | Loss: 0.2914 | Accuracy: 88.65% | Time: 9.41s
# Epoch 263 | Loss: 0.2237 | Accuracy: 90.78% | Time: 9.41s
# Epoch 264 | Loss: 0.2480 | Accuracy: 89.36% | Time: 9.36s
# Epoch 265 | Loss: 0.2325 | Accuracy: 89.36% | Time: 9.61s
# Epoch 266 | Loss: 0.1358 | Accuracy: 96.45% | Time: 9.32s
# Epoch 267 | Loss: 0.1894 | Accuracy: 92.91% | Time: 9.22s
# Epoch 268 | Loss: 0.1838 | Accuracy: 92.91% | Time: 9.76s
# Epoch 269 | Loss: 0.2102 | Accuracy: 88.65% | Time: 9.83s
# Epoch 270 | Loss: 0.2190 | Accuracy: 93.62% | Time: 9.30s
# Epoch 271 | Loss: 0.2077 | Accuracy: 93.62% | Time: 9.58s
# Epoch 272 | Loss: 0.1781 | Accuracy: 93.62% | Time: 9.54s
# Epoch 273 | Loss: 0.1297 | Accuracy: 96.45% | Time: 9.32s
# Epoch 274 | Loss: 0.1529 | Accuracy: 95.04% | Time: 9.68s
# Epoch 275 | Loss: 0.2064 | Accuracy: 95.74% | Time: 9.41s
# Epoch 276 | Loss: 0.1710 | Accuracy: 93.62% | Time: 9.48s
# Epoch 277 | Loss: 0.1714 | Accuracy: 92.91% | Time: 9.65s
# Epoch 278 | Loss: 0.2000 | Accuracy: 90.78% | Time: 9.66s
# Epoch 279 | Loss: 0.1621 | Accuracy: 92.91% | Time: 9.61s
# Epoch 280 | Loss: 0.1654 | Accuracy: 93.62% | Time: 9.34s
# Epoch 281 | Loss: 0.1089 | Accuracy: 96.45% | Time: 9.45s
# Epoch 282 | Loss: 0.1256 | Accuracy: 95.04% | Time: 9.67s
# Epoch 283 | Loss: 0.1736 | Accuracy: 93.62% | Time: 9.75s
# Epoch 284 | Loss: 0.1813 | Accuracy: 91.49% | Time: 9.42s
# Epoch 285 | Loss: 0.1180 | Accuracy: 96.45% | Time: 9.63s
# Epoch 286 | Loss: 0.1395 | Accuracy: 93.62% | Time: 9.44s
# Epoch 287 | Loss: 0.2173 | Accuracy: 91.49% | Time: 9.56s
# Epoch 288 | Loss: 0.1373 | Accuracy: 95.04% | Time: 9.18s
# Epoch 289 | Loss: 0.1300 | Accuracy: 97.16% | Time: 9.60s
# Epoch 290 | Loss: 0.0935 | Accuracy: 97.87% | Time: 9.54s
# Epoch 291 | Loss: 0.1048 | Accuracy: 96.45% | Time: 9.33s
# Epoch 292 | Loss: 0.1275 | Accuracy: 93.62% | Time: 9.45s
# Epoch 293 | Loss: 0.1810 | Accuracy: 90.78% | Time: 9.15s
# Epoch 294 | Loss: 0.1226 | Accuracy: 95.74% | Time: 9.24s
# Epoch 295 | Loss: 0.1185 | Accuracy: 95.74% | Time: 9.60s
# Epoch 296 | Loss: 0.0794 | Accuracy: 99.29% | Time: 9.25s
# Epoch 297 | Loss: 0.1323 | Accuracy: 96.45% | Time: 9.25s
# Epoch 298 | Loss: 0.1858 | Accuracy: 92.91% | Time: 9.59s
# Epoch 299 | Loss: 0.0888 | Accuracy: 97.87% | Time: 9.67s
# Epoch 300 | Loss: 0.1353 | Accuracy: 92.91% | Time: 9.73s
# Epoch 301 | Loss: 0.1253 | Accuracy: 93.62% | Time: 9.45s
# Epoch 302 | Loss: 0.0920 | Accuracy: 96.45% | Time: 9.69s
# Epoch 303 | Loss: 0.0904 | Accuracy: 97.87% | Time: 9.56s
# Epoch 304 | Loss: 0.0753 | Accuracy: 97.87% | Time: 9.36s
# Epoch 305 | Loss: 0.1261 | Accuracy: 96.45% | Time: 9.46s
# Epoch 306 | Loss: 0.0904 | Accuracy: 96.45% | Time: 9.60s
# Epoch 307 | Loss: 0.0829 | Accuracy: 97.87% | Time: 9.40s
# Epoch 308 | Loss: 0.1183 | Accuracy: 95.74% | Time: 9.81s
# Epoch 309 | Loss: 0.0880 | Accuracy: 97.16% | Time: 10.04s
# Epoch 310 | Loss: 0.0817 | Accuracy: 97.16% | Time: 9.57s
# Epoch 311 | Loss: 0.1095 | Accuracy: 96.45% | Time: 9.66s
# Epoch 312 | Loss: 0.1512 | Accuracy: 95.74% | Time: 9.94s
# Epoch 313 | Loss: 0.1527 | Accuracy: 94.33% | Time: 9.49s
# Epoch 314 | Loss: 0.1108 | Accuracy: 95.74% | Time: 9.53s
# Epoch 315 | Loss: 0.0616 | Accuracy: 97.87% | Time: 9.95s
# Epoch 316 | Loss: 0.0656 | Accuracy: 97.87% | Time: 9.64s
# Epoch 317 | Loss: 0.1128 | Accuracy: 95.74% | Time: 9.70s
# Epoch 318 | Loss: 0.1255 | Accuracy: 93.62% | Time: 9.74s
# Epoch 319 | Loss: 0.0664 | Accuracy: 97.87% | Time: 9.72s
# Epoch 320 | Loss: 0.0908 | Accuracy: 95.04% | Time: 9.72s
# Epoch 321 | Loss: 0.1295 | Accuracy: 95.04% | Time: 9.62s
# Epoch 322 | Loss: 0.0969 | Accuracy: 97.16% | Time: 9.84s
# Epoch 323 | Loss: 0.0724 | Accuracy: 99.29% | Time: 9.58s
# Epoch 324 | Loss: 0.0854 | Accuracy: 96.45% | Time: 9.73s
# Epoch 325 | Loss: 0.0949 | Accuracy: 96.45% | Time: 10.07s
# Epoch 326 | Loss: 0.0690 | Accuracy: 98.58% | Time: 9.54s
# Epoch 327 | Loss: 0.0920 | Accuracy: 97.16% | Time: 9.52s
# Epoch 328 | Loss: 0.1361 | Accuracy: 95.74% | Time: 9.95s
# Epoch 329 | Loss: 0.0802 | Accuracy: 97.16% | Time: 9.98s
# Epoch 330 | Loss: 0.0983 | Accuracy: 97.16% | Time: 9.83s
# Epoch 331 | Loss: 0.0815 | Accuracy: 97.87% | Time: 9.63s
# Epoch 332 | Loss: 0.1106 | Accuracy: 98.58% | Time: 9.79s
# Epoch 333 | Loss: 0.1034 | Accuracy: 96.45% | Time: 9.50s
# Epoch 334 | Loss: 0.1117 | Accuracy: 95.74% | Time: 9.75s
# Epoch 335 | Loss: 0.1250 | Accuracy: 93.62% | Time: 9.77s
# Epoch 336 | Loss: 0.0923 | Accuracy: 97.87% | Time: 9.67s
# Epoch 337 | Loss: 0.1133 | Accuracy: 94.33% | Time: 9.78s
# Epoch 338 | Loss: 0.0629 | Accuracy: 99.29% | Time: 9.59s
# Epoch 339 | Loss: 0.0717 | Accuracy: 98.58% | Time: 9.73s
# Epoch 340 | Loss: 0.1331 | Accuracy: 95.74% | Time: 9.69s
# Epoch 341 | Loss: 0.0803 | Accuracy: 97.16% | Time: 9.69s
# Epoch 342 | Loss: 0.0686 | Accuracy: 97.16% | Time: 9.63s
# Epoch 343 | Loss: 0.1196 | Accuracy: 93.62% | Time: 9.59s
# Epoch 344 | Loss: 0.0789 | Accuracy: 96.45% | Time: 9.53s
# Epoch 345 | Loss: 0.0765 | Accuracy: 98.58% | Time: 9.78s
# Epoch 346 | Loss: 0.1001 | Accuracy: 97.16% | Time: 10.10s
# Epoch 347 | Loss: 0.1085 | Accuracy: 97.87% | Time: 9.61s
# Epoch 348 | Loss: 0.0983 | Accuracy: 97.16% | Time: 9.74s
# Epoch 349 | Loss: 0.1101 | Accuracy: 94.33% | Time: 9.63s
# Epoch 350 | Loss: 0.0589 | Accuracy: 97.87% | Time: 9.78s
#
# Model Summary:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# CalmnessAnalysisModel                    [512, 25]                 [512, 3]                  --                        --
# ├─LSTM: 1-1                              [512, 1, 25]              [512, 1, 512]             579,584                   296,747,008
# ├─Linear: 1-2                            [512, 512]                [512, 128]                65,664                    33,619,968
# ├─ReLU: 1-3                              [512, 128]                [512, 128]                --                        --
# ├─Dropout: 1-4                           [512, 128]                [512, 128]                --                        --
# ├─Linear: 1-5                            [512, 128]                [512, 3]                  387                       198,144
# ============================================================================================================================================
# Total params: 645,635
# Trainable params: 645,635
# Non-trainable params: 0
# Total mult-adds (M): 330.57
# ============================================================================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 2.63
# Params size (MB): 2.58
# Estimated Total Size (MB): 5.27
# ============================================================================================================================================
#
# Total GPU Training Time: 3317.14 seconds
# Hyperparameters Used:
# Learning Rate: 0.005
# Epochs: 350
# Batch Size: 512
# Input Dimension: 25
# Hidden Dimension: 256
# Dropout: 0.3
# Optimizer: Adam
# Criterion: CrossEntropyLoss

# %%
import torch
import torch.nn as nn
import librosa
import numpy as np
import pywt
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Ensure device compatibility
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ===========================
# 1. Load Trained Model
# ===========================
class CalmnessAnalysisModel(nn.Module):
    def __init__(self, input_dim=25, hidden_dim=256, num_classes=3):
        super(CalmnessAnalysisModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(hidden_dim * 2, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.3)

    def forward(self, audio_features):
        layer_outputs = {}

        # Input to LSTM
        audio_features = audio_features.unsqueeze(1)  # Reshape for LSTM
        lstm_out, _ = self.lstm(audio_features)
        lstm_out = lstm_out[:, -1, :]  # Take last time-step output
        layer_outputs["LSTM Output"] = lstm_out.detach().cpu().numpy()

        # Fully Connected Layer 1
        x = self.relu(self.fc1(lstm_out))
        layer_outputs["FC1 Output (ReLU)"] = x.detach().cpu().numpy()

        # Dropout Layer
        x = self.dropout(x)
        layer_outputs["Dropout Output"] = x.detach().cpu().numpy()

        # Fully Connected Layer 2 (Final Output)
        x = self.fc2(x)
        layer_outputs["Final Output (Logits)"] = x.detach().cpu().numpy()

        return x, layer_outputs

# Load the trained model
model = CalmnessAnalysisModel(input_dim=25).to(device)
model.load_state_dict(torch.load("/kaggle/working/calmness_analysis_model.pth", map_location=device))
model.eval()

# ===========================
# 2. Load Sample Audio from Each Class
# ===========================
dataset_path = "/kaggle/input/qmsat-dataset/ATS-data"
categories = ["Music", "Normal(Silence)", "Tilawat-e-QuranPak"]

sample_files = {}
for category in categories:
    category_path = os.path.join(dataset_path, category)
    for file in os.listdir(category_path):
        if file.endswith(".wav"):
            sample_files[category] = os.path.join(category_path, file)
            break  # Pick only one sample per category

# ===========================
# 3. Feature Extraction Function
# ===========================
def extract_features(file_path):
    waveform, sr = librosa.load(file_path, sr=16000)

    # MFCC Features
    mfccs = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=13).mean(axis=1)

    # Time Features (Zero-Crossing Rate & RMS)
    zcr = librosa.feature.zero_crossing_rate(waveform)[0].mean()
    rms = librosa.feature.rms(y=waveform)[0].mean()

    # Wavelet Transform Features
    coeffs = pywt.wavedec(waveform, 'db4', level=4)
    wavelet_features = []
    for c in coeffs:
        wavelet_features.append(np.mean(c) if c.size > 0 else 0)
        wavelet_features.append(np.std(c) if c.size > 0 else 0)
    wavelet_features = wavelet_features[:10]  # Keep first 10 features

    return np.concatenate([mfccs, [zcr, rms], wavelet_features])

# ===========================
# 4. Process Audio Through Model
# ===========================
layer_outputs_per_class = {}

for category, file_path in sample_files.items():
    print(f"Processing {category}: {file_path}")

    # Extract features
    features = extract_features(file_path)
    features_tensor = torch.tensor(features, dtype=torch.float32).to(device).unsqueeze(0)

    # Pass through the model and get layer outputs
    _, layer_outputs = model(features_tensor)
    layer_outputs_per_class[category] = layer_outputs

# ===========================
# 5. Visualization of Layer Outputs
# ===========================
sns.set_style("whitegrid")
fig, axes = plt.subplots(len(layer_outputs), len(categories), figsize=(15, 12))

# Iterate over layers
for layer_idx, (layer_name, _) in enumerate(layer_outputs_per_class["Music"].items()):
    for category_idx, category in enumerate(categories):
        output_data = layer_outputs_per_class[category][layer_name]

        # Plot as a heatmap for better visualization
        sns.heatmap(output_data, ax=axes[layer_idx, category_idx], cmap="coolwarm", cbar=True)
        axes[layer_idx, category_idx].set_title(f"{category} - {layer_name}")

plt.tight_layout()
plt.savefig("/kaggle/working/layer_visualization.jpeg", dpi=300)
plt.show()

print("Layer-wise visualization saved as 'layer_visualization.jpeg'.")
# Out:
# Using device: cuda
# Processing Music: /kaggle/input/qmsat-dataset/ATS-data/Music/13_music_f_3.wav
# Processing Normal(Silence): /kaggle/input/qmsat-dataset/ATS-data/Normal(Silence)/10_normal_m_8.wav
# Processing Tilawat-e-QuranPak: /kaggle/input/qmsat-dataset/ATS-data/Tilawat-e-QuranPak/1_quran_f_23.wav
# <ipython-input-3-3846a3853707>:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/kaggle/working/calmness_analysis_model.pth", map_location=device))
# Layer-wise visualization saved as 'layer_visualization.jpeg'.

# %%
import torch
import torch.nn as nn
import librosa
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pywt

# Set visualization style
sns.set_style("whitegrid")

# Load trained model
model_path = "/kaggle/working/calmness_analysis_model.pth"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define class names
class_labels = {0: "Music", 1: "Normal (Silence)", 2: "Tilawat-e-QuranPak"}

# Load model
class CalmnessAnalysisModel(nn.Module):
    def __init__(self, input_dim=25, hidden_dim=256, num_classes=3):
        super(CalmnessAnalysisModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc1 = nn.Linear(hidden_dim * 2, 128)
        self.fc2 = nn.Linear(128, num_classes)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.3)

    def forward(self, audio_features):
        audio_features = audio_features.unsqueeze(1)
        lstm_out, _ = self.lstm(audio_features)
        lstm_out = lstm_out[:, -1, :]
        fc1_out = self.relu(self.fc1(lstm_out))  # Extract FC1 activations
        x = self.dropout(fc1_out)
        x = self.fc2(x)
        return lstm_out, fc1_out, x  # Return FC1 activations

# Load the trained model
model = CalmnessAnalysisModel(input_dim=25).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# =====================
# 1. Load & Preprocess an Example Audio from Each Class
# =====================

def extract_features(waveform, sr=16000):
    """Extracts MFCC, time-domain, and wavelet features."""
    # MFCC Features
    mfccs = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=13).mean(axis=1)

    # Time-domain Features
    zcr = librosa.feature.zero_crossing_rate(waveform)[0].mean()
    rms = librosa.feature.rms(y=waveform)[0].mean()
    time_features = np.array([zcr, rms])

    # Wavelet Features
    coeffs = pywt.wavedec(waveform, 'db4', level=4)
    wavelet_features = [np.mean(c) if c.size > 0 else 0 for c in coeffs[:5]] + \
                       [np.std(c) if c.size > 0 else 0 for c in coeffs[:5]]

    # Combine all features
    return np.concatenate([mfccs, time_features, wavelet_features]), time_features, wavelet_features

# Load sample audio files from each class
root_dir = "/kaggle/input/qmsat-dataset/ATS-data"
sample_files = {}

for category in os.listdir(root_dir):
    category_path = os.path.join(root_dir, category)
    if os.path.isdir(category_path):
        for file in os.listdir(category_path):
            if file.endswith(".wav"):
                sample_files[category] = os.path.join(category_path, file)
                break  # Only take one sample per category

# Prepare storage for visualization
waveforms = {}
mfcc_transforms = {}
time_features_store = {}
wavelet_features_store = {}
lstm_outputs = {}
fc1_outputs = {}
final_outputs = {}

fig, axes = plt.subplots(len(sample_files), 7, figsize=(22, 12))

# =====================
# 2. Pass Through Model and Visualize Transformations
# =====================

for idx, (category, file_path) in enumerate(sample_files.items()):
    # Load audio
    waveform, sr = librosa.load(file_path, sr=16000)
    waveforms[category] = waveform

    # Extract features
    features, time_features, wavelet_features = extract_features(waveform)
    features_tensor = torch.tensor(features, dtype=torch.float32).to(device).unsqueeze(0)

    # Pass through model
    with torch.no_grad():
        lstm_out, fc1_out, final_out = model(features_tensor)

    # Store transformations
    mfcc_transforms[category] = features[:13]  # MFCC components
    time_features_store[category] = time_features  # ZCR & RMS
    wavelet_features_store[category] = wavelet_features  # Wavelet Features
    lstm_outputs[category] = lstm_out.cpu().numpy().squeeze()  # LSTM Hidden state
    fc1_outputs[category] = fc1_out.cpu().numpy().squeeze()  # Corrected FC1 output
    final_outputs[category] = final_out.cpu().numpy().squeeze()  # Final output (logits)

    # =====================
    # 3. Plot Layer-by-Layer Transformations
    # =====================

    # 1. Original Waveform
    axes[idx, 0].plot(waveform, color="blue", alpha=0.7)
    axes[idx, 0].set_title(f"{category}\nOriginal Waveform", fontsize=10)

    # 2. MFCC Features
    axes[idx, 1].bar(range(13), mfcc_transforms[category], color="purple")
    axes[idx, 1].set_title(f"{category}\nMFCC Features", fontsize=10)

    # 3. Time-domain Features (ZCR & RMS)
    axes[idx, 2].bar(["ZCR", "RMS"], time_features_store[category], color="cyan")
    axes[idx, 2].set_title(f"{category}\nTime-domain Features", fontsize=10)

    # 4. Wavelet Features
    axes[idx, 3].bar(range(len(wavelet_features_store[category])), wavelet_features_store[category], color="brown")
    axes[idx, 3].set_title(f"{category}\nWavelet Features", fontsize=10)

    # 5. LSTM Hidden State
    axes[idx, 4].plot(lstm_outputs[category], color="green")
    axes[idx, 4].set_title(f"{category}\nLSTM Hidden State", fontsize=10)

    # 6. Fully Connected Layer Output
    if len(fc1_outputs[category]) == 128:
        axes[idx, 5].bar(range(128), fc1_outputs[category], color="orange")
        axes[idx, 5].set_title(f"{category}\nFully Connected Output", fontsize=10)
    else:
        print(f"Warning: Unexpected shape {fc1_outputs[category].shape} in FC1 output.")

    # 7. Softmax Prediction (Final Probabilities)
    softmax_probs = torch.softmax(torch.tensor(final_outputs[category]), dim=0).numpy()
    axes[idx, 6].bar(list(class_labels.values()), softmax_probs, color="red")
    axes[idx, 6].set_title(f"{category}\nPrediction Probabilities", fontsize=10)

# Adjust layout and fix title overlaps
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.suptitle("Model Feature Transformations for Different Audio Classes", fontsize=16, fontweight='bold')
plt.savefig("/kaggle/working/model_visualization.jpeg", dpi=300)
plt.show()
# Out:
# <ipython-input-4-6bc99b08a138>:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

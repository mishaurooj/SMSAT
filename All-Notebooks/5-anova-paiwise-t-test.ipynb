# %%
import os
import librosa
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_style("whitegrid")

# Define categories
categories = {
    "SpiritualMeditation": 0,
    "Music": 1,
    "Normal(Silence)": 2
}

# Define feature names
feature_names = (
    ["MFCC_{}".format(i) for i in range(13)] +  # 13 MFCC features
    ["ZCR", "RMS"] +  # 2 Time-domain features
    ["Wavelet_{}".format(i) for i in range(10)]  # 10 Wavelet features
)

# Function to extract features
def extract_features(file_path):
    waveform, sr = librosa.load(file_path, sr=16000)

    # MFCC Features
    mfccs = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=13).mean(axis=1)

    # Time-Domain Features
    zcr = librosa.feature.zero_crossing_rate(waveform)[0].mean()
    rms = librosa.feature.rms(y=waveform)[0].mean()

    # Wavelet Transform Features
    coeffs = librosa.feature.mfcc(y=waveform, sr=sr, n_mfcc=10).mean(axis=1)

    # Combine features
    return np.concatenate([mfccs, [zcr, rms], coeffs])

# Load dataset
root_dir = "/kaggle/input/qmsat-dataset/ATS-data"
data = []

for category, label in categories.items():
    category_path = os.path.join(root_dir, category)
    if not os.path.exists(category_path):
        print(f"Skipping {category} (Folder not found)")
        continue
    for file in os.listdir(category_path):
        if file.endswith(".wav"):
            features = extract_features(os.path.join(category_path, file))
            data.append([category] + list(features))

# Convert to DataFrame
df = pd.DataFrame(data, columns=["Category"] + feature_names)

# Initialize calmness counter
calmness_count = {"SpiritualMeditation": 0, "Music": 0, "Normal(Silence)": 0}

# Create a results dictionary for logging
results = []

# Perform statistical tests for each feature
for feature in feature_names:
    spiritual_meditation_values = df[df["Category"] == "SpiritualMeditation"][feature]
    music_values = df[df["Category"] == "Music"][feature]
    normal_values = df[df["Category"] == "Normal(Silence)"][feature]

    # Calculate mean values
    mean_spiritual_meditation = np.mean(spiritual_meditation_values)
    mean_music = np.mean(music_values)
    mean_normal = np.mean(normal_values)

    # ANOVA test (Compare all three distributions)
    f_stat, p_anova = stats.f_oneway(spiritual_meditation_values, music_values, normal_values)

    # T-tests (Pairwise comparisons)
    t_sm_m, p_sm_m = stats.ttest_ind(spiritual_meditation_values, music_values, equal_var=False)
    t_sm_n, p_sm_n = stats.ttest_ind(spiritual_meditation_values, normal_values, equal_var=False)
    t_mn, p_mn = stats.ttest_ind(music_values, normal_values, equal_var=False)

    # Determine calmest category
    calmest = "SpiritualMeditation" if mean_spiritual_meditation < mean_music and mean_spiritual_meditation < mean_normal else \
              "Music" if mean_music < mean_spiritual_meditation and mean_music < mean_normal else \
              "Normal(Silence)"

    # Print results
    print(f"Feature: {feature}")
    print(f"Mean values: SpiritualMeditation = {mean_spiritual_meditation:.4f}, Normal = {mean_normal:.4f}, Music = {mean_music:.4f}")
    print(f"Comparison: {feature}(SpiritualMeditation) {'<' if mean_spiritual_meditation < mean_normal else '>'} {feature}(Normal) {'<' if mean_normal < mean_music else '>'} {feature}(Music)")
    print(f"ANOVA p-value: {p_anova:.4f}")
    print(f"T-tests: SpiritualMeditation vs Music p = {p_sm_m:.4f}, SpiritualMeditation vs Normal p = {p_sm_n:.4f}, Music vs Normal p = {p_mn:.4f}")
    print(f"Calmest category based on {feature}: {calmest}\n")

    # Increment calmness counter
    calmness_count[calmest] += 1

    # Save results
    results.append([feature, mean_spiritual_meditation, mean_music, mean_normal, calmest, p_anova, p_sm_m, p_sm_n, p_mn])

    # Visualization
    plt.figure(figsize=(8, 5))
    sns.boxplot(x="Category", y=feature, data=df, palette="coolwarm")
    plt.title(f"{feature} Distribution across Categories")
    plt.xlabel("Category")
    plt.ylabel(feature)
    plt.savefig(f"/kaggle/working/feature_{feature}.jpeg", dpi=300)  # Save graph as JPEG
    plt.close()

# Print final calmness counts
print("\n=== Calmness Count Summary ===")
for category, count in calmness_count.items():
    print(f"{category}: {count} features")

# Determine the overall calmest category
overall_calmest = max(calmness_count, key=calmness_count.get)
print(f"\nThe overall calmest category based on all features is: {overall_calmest}")

# Save results to an Excel file
df_results = pd.DataFrame(results, columns=[
    "Feature", "Mean SpiritualMeditation", "Mean Music", "Mean Normal",
    "Calmest Category", "ANOVA p-value", "T-test SpiritualMeditation vs Music",
    "T-test SpiritualMeditation vs Normal", "T-test Music vs Normal"
])
df_results.to_excel("/kaggle/working/calmness_analysis_results.xlsx", index=False)

print("\nResults saved to calmness_analysis_results.xlsx and feature visualizations saved as JPEG.")
# Out:
# Feature: MFCC_0
# Mean values: SpiritualMeditation = -254.2791, Normal = -249.5712, Music = -245.2362
# Comparison: MFCC_0(SpiritualMeditation) < MFCC_0(Normal) < MFCC_0(Music)
# ANOVA p-value: 0.8719
# T-tests: SpiritualMeditation vs Music p = 0.5749, SpiritualMeditation vs Normal p = 0.7915, Music vs Normal p = 0.8051
# Calmest category based on MFCC_0: SpiritualMeditation
#
# Feature: MFCC_1
# Mean values: SpiritualMeditation = 93.7285, Normal = 87.9650, Music = 99.2803
# Comparison: MFCC_1(SpiritualMeditation) > MFCC_1(Normal) < MFCC_1(Music)
# ANOVA p-value: 0.6528
# T-tests: SpiritualMeditation vs Music p = 0.6550, SpiritualMeditation vs Normal p = 0.6439, Music vs Normal p = 0.3522
# Calmest category based on MFCC_1: Normal(Silence)
#
# Feature: MFCC_2
# Mean values: SpiritualMeditation = -6.4426, Normal = -9.1582, Music = -3.7299
# Comparison: MFCC_2(SpiritualMeditation) > MFCC_2(Normal) < MFCC_2(Music)
# ANOVA p-value: 0.7109
# T-tests: SpiritualMeditation vs Music p = 0.6854, SpiritualMeditation vs Normal p = 0.6800, Music vs Normal p = 0.4101
# Calmest category based on MFCC_2: Normal(Silence)
#
# Feature: MFCC_3
# Mean values: SpiritualMeditation = 12.7264, Normal = 9.7897, Music = 12.8667
# Comparison: MFCC_3(SpiritualMeditation) > MFCC_3(Normal) < MFCC_3(Music)
# ANOVA p-value: 0.3894
# T-tests: SpiritualMeditation vs Music p = 0.9579, SpiritualMeditation vs Normal p = 0.2322, Music vs Normal p = 0.2250
# Calmest category based on MFCC_3: Normal(Silence)
#
# Feature: MFCC_4
# Mean values: SpiritualMeditation = 11.3003, Normal = 11.4780, Music = 12.4645
# Comparison: MFCC_4(SpiritualMeditation) < MFCC_4(Normal) < MFCC_4(Music)
# ANOVA p-value: 0.8371
# T-tests: SpiritualMeditation vs Music p = 0.5949, SpiritualMeditation vs Normal p = 0.9315, Music vs Normal p = 0.6333
# Calmest category based on MFCC_4: SpiritualMeditation
#
# Feature: MFCC_5
# Mean values: SpiritualMeditation = 12.1020, Normal = 12.6197, Music = 13.8407
# Comparison: MFCC_5(SpiritualMeditation) < MFCC_5(Normal) < MFCC_5(Music)
# ANOVA p-value: 0.4863
# T-tests: SpiritualMeditation vs Music p = 0.2338, SpiritualMeditation vs Normal p = 0.7289, Music vs Normal p = 0.4145
# Calmest category based on MFCC_5: SpiritualMeditation
#
# Feature: MFCC_6
# Mean values: SpiritualMeditation = -3.6092, Normal = -4.4564, Music = -2.9514
# Comparison: MFCC_6(SpiritualMeditation) > MFCC_6(Normal) < MFCC_6(Music)
# ANOVA p-value: 0.5839
# T-tests: SpiritualMeditation vs Music p = 0.6441, SpiritualMeditation vs Normal p = 0.5689, Music vs Normal p = 0.3095
# Calmest category based on MFCC_6: Normal(Silence)
#
# Feature: MFCC_7
# Mean values: SpiritualMeditation = 4.6322, Normal = 4.2813, Music = 4.4587
# Comparison: MFCC_7(SpiritualMeditation) > MFCC_7(Normal) < MFCC_7(Music)
# ANOVA p-value: 0.9222
# T-tests: SpiritualMeditation vs Music p = 0.8536, SpiritualMeditation vs Normal p = 0.6811, Music vs Normal p = 0.8315
# Calmest category based on MFCC_7: Normal(Silence)
#
# Feature: MFCC_8
# Mean values: SpiritualMeditation = -3.0367, Normal = -2.5192, Music = -3.3189
# Comparison: MFCC_8(SpiritualMeditation) < MFCC_8(Normal) > MFCC_8(Music)
# ANOVA p-value: 0.6412
# T-tests: SpiritualMeditation vs Music p = 0.7593, SpiritualMeditation vs Normal p = 0.5451, Music vs Normal p = 0.3364
# Calmest category based on MFCC_8: Music
#
# Feature: MFCC_9
# Mean values: SpiritualMeditation = 3.4204, Normal = 4.5822, Music = 3.6432
# Comparison: MFCC_9(SpiritualMeditation) < MFCC_9(Normal) > MFCC_9(Music)
# ANOVA p-value: 0.4880
# T-tests: SpiritualMeditation vs Music p = 0.8399, SpiritualMeditation vs Normal p = 0.2518, Music vs Normal p = 0.3460
# Calmest category based on MFCC_9: SpiritualMeditation
#
# Feature: MFCC_10
# Mean values: SpiritualMeditation = -3.4915, Normal = -3.0753, Music = -3.0256
# Comparison: MFCC_10(SpiritualMeditation) < MFCC_10(Normal) < MFCC_10(Music)
# ANOVA p-value: 0.7996
# T-tests: SpiritualMeditation vs Music p = 0.5728, SpiritualMeditation vs Normal p = 0.5751, Music vs Normal p = 0.9453
# Calmest category based on MFCC_10: SpiritualMeditation
#
# Feature: MFCC_11
# Mean values: SpiritualMeditation = 1.7940, Normal = 2.9238, Music = 2.0206
# Comparison: MFCC_11(SpiritualMeditation) < MFCC_11(Normal) > MFCC_11(Music)
# ANOVA p-value: 0.3404
# T-tests: SpiritualMeditation vs Music p = 0.7905, SpiritualMeditation vs Normal p = 0.1718, Music vs Normal p = 0.2473
# Calmest category based on MFCC_11: SpiritualMeditation
#
# Feature: MFCC_12
# Mean values: SpiritualMeditation = -3.5625, Normal = -2.8183, Music = -3.6268
# Comparison: MFCC_12(SpiritualMeditation) < MFCC_12(Normal) > MFCC_12(Music)
# ANOVA p-value: 0.4586
# T-tests: SpiritualMeditation vs Music p = 0.9277, SpiritualMeditation vs Normal p = 0.3338, Music vs Normal p = 0.2452
# Calmest category based on MFCC_12: Music
#
# Feature: ZCR
# Mean values: SpiritualMeditation = 0.2739, Normal = 0.2693, Music = 0.2480
# Comparison: ZCR(SpiritualMeditation) > ZCR(Normal) > ZCR(Music)
# ANOVA p-value: 0.5760
# T-tests: SpiritualMeditation vs Music p = 0.3272, SpiritualMeditation vs Normal p = 0.8625, Music vs Normal p = 0.4141
# Calmest category based on ZCR: Music
#
# Feature: RMS
# Mean values: SpiritualMeditation = 0.0596, Normal = 0.0591, Music = 0.0644
# Comparison: RMS(SpiritualMeditation) > RMS(Normal) < RMS(Music)
# ANOVA p-value: 0.9163
# T-tests: SpiritualMeditation vs Music p = 0.7445, SpiritualMeditation vs Normal p = 0.9747, Music vs Normal p = 0.6906
# Calmest category based on RMS: Normal(Silence)
#
# Feature: Wavelet_0
# Mean values: SpiritualMeditation = -254.2791, Normal = -249.5712, Music = -245.2362
# Comparison: Wavelet_0(SpiritualMeditation) < Wavelet_0(Normal) < Wavelet_0(Music)
# ANOVA p-value: 0.8719
# T-tests: SpiritualMeditation vs Music p = 0.5749, SpiritualMeditation vs Normal p = 0.7915, Music vs Normal p = 0.8051
# Calmest category based on Wavelet_0: SpiritualMeditation
#
# Feature: Wavelet_1
# Mean values: SpiritualMeditation = 93.7285, Normal = 87.9650, Music = 99.2803
# Comparison: Wavelet_1(SpiritualMeditation) > Wavelet_1(Normal) < Wavelet_1(Music)
# ANOVA p-value: 0.6528
# T-tests: SpiritualMeditation vs Music p = 0.6550, SpiritualMeditation vs Normal p = 0.6439, Music vs Normal p = 0.3522
# Calmest category based on Wavelet_1: Normal(Silence)
#
# Feature: Wavelet_2
# Mean values: SpiritualMeditation = -6.4426, Normal = -9.1582, Music = -3.7299
# Comparison: Wavelet_2(SpiritualMeditation) > Wavelet_2(Normal) < Wavelet_2(Music)
# ANOVA p-value: 0.7109
# T-tests: SpiritualMeditation vs Music p = 0.6854, SpiritualMeditation vs Normal p = 0.6800, Music vs Normal p = 0.4101
# Calmest category based on Wavelet_2: Normal(Silence)
#
# Feature: Wavelet_3
# Mean values: SpiritualMeditation = 12.7264, Normal = 9.7897, Music = 12.8667
# Comparison: Wavelet_3(SpiritualMeditation) > Wavelet_3(Normal) < Wavelet_3(Music)
# ANOVA p-value: 0.3894
# T-tests: SpiritualMeditation vs Music p = 0.9579, SpiritualMeditation vs Normal p = 0.2322, Music vs Normal p = 0.2250
# Calmest category based on Wavelet_3: Normal(Silence)
#
# Feature: Wavelet_4
# Mean values: SpiritualMeditation = 11.3003, Normal = 11.4780, Music = 12.4645
# Comparison: Wavelet_4(SpiritualMeditation) < Wavelet_4(Normal) < Wavelet_4(Music)
# ANOVA p-value: 0.8371
# T-tests: SpiritualMeditation vs Music p = 0.5949, SpiritualMeditation vs Normal p = 0.9315, Music vs Normal p = 0.6333
# Calmest category based on Wavelet_4: SpiritualMeditation
#
# Feature: Wavelet_5
# Mean values: SpiritualMeditation = 12.1020, Normal = 12.6197, Music = 13.8407
# Comparison: Wavelet_5(SpiritualMeditation) < Wavelet_5(Normal) < Wavelet_5(Music)
# ANOVA p-value: 0.4863
# T-tests: SpiritualMeditation vs Music p = 0.2338, SpiritualMeditation vs Normal p = 0.7289, Music vs Normal p = 0.4145
# Calmest category based on Wavelet_5: SpiritualMeditation
#
# Feature: Wavelet_6
# Mean values: SpiritualMeditation = -3.6092, Normal = -4.4564, Music = -2.9514
# Comparison: Wavelet_6(SpiritualMeditation) > Wavelet_6(Normal) < Wavelet_6(Music)
# ANOVA p-value: 0.5839
# T-tests: SpiritualMeditation vs Music p = 0.6441, SpiritualMeditation vs Normal p = 0.5689, Music vs Normal p = 0.3095
# Calmest category based on Wavelet_6: Normal(Silence)
#
# Feature: Wavelet_7
# Mean values: SpiritualMeditation = 4.6322, Normal = 4.2813, Music = 4.4587
# Comparison: Wavelet_7(SpiritualMeditation) > Wavelet_7(Normal) < Wavelet_7(Music)
# ANOVA p-value: 0.9222
# T-tests: SpiritualMeditation vs Music p = 0.8536, SpiritualMeditation vs Normal p = 0.6811, Music vs Normal p = 0.8315
# Calmest category based on Wavelet_7: Normal(Silence)
#
# Feature: Wavelet_8
# Mean values: SpiritualMeditation = -3.0367, Normal = -2.5192, Music = -3.3189
# Comparison: Wavelet_8(SpiritualMeditation) < Wavelet_8(Normal) > Wavelet_8(Music)
# ANOVA p-value: 0.6412
# T-tests: SpiritualMeditation vs Music p = 0.7593, SpiritualMeditation vs Normal p = 0.5451, Music vs Normal p = 0.3364
# Calmest category based on Wavelet_8: Music
#
# Feature: Wavelet_9
# Mean values: SpiritualMeditation = 3.4204, Normal = 4.5822, Music = 3.6432
# Comparison: Wavelet_9(SpiritualMeditation) < Wavelet_9(Normal) > Wavelet_9(Music)
# ANOVA p-value: 0.4880
# T-tests: SpiritualMeditation vs Music p = 0.8399, SpiritualMeditation vs Normal p = 0.2518, Music vs Normal p = 0.3460
# Calmest category based on Wavelet_9: SpiritualMeditation
#
#
# === Calmness Count Summary ===
# SpiritualMeditation: 10 features
# Music: 4 features
# Normal(Silence): 11 features
#
# The overall calmest category based on all features is: Normal(Silence)
#
# Results saved to calmness_analysis_results.xlsx and feature visualizations saved as JPEG.
